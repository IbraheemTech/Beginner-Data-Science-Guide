# %%
import numpy as np
import random

# %%
#Reading the csv file
df_exam = pd.read_csv('StudentsPerformance.csv')

# %% [markdown]
# # Create Index

# %%
#Creating non repititive values for the index
new_index = np.arange(0,1000)

# %%
#shuffling the indexes
random.shuffle(new_index)

# %%
df_exam['new_index'] = new_index

# %%
df_exam
# Out:
#            gender race/ethnicity parental level of education         lunch  \
# new_index
# 889        female        group B           bachelor's degree      standard
# 445        female        group C                some college      standard
# 905        female        group B             master's degree      standard
# 605          male        group A          associate's degree  free/reduced
# 545          male        group C                some college      standard
# ...           ...            ...                         ...           ...
# 411        female        group E             master's degree      standard
# 571          male        group C                 high school  free/reduced
# 610        female        group C                 high school  free/reduced
# 393        female        group D                some college      standard
# 550        female        group D                some college  free/reduced
#
# ...

# %% [markdown]
# # Set Index

# %%
#Set new_index column as index
df_exam.set_index('new_index', inplace = True)
df_exam
# Out:
#            gender race/ethnicity parental level of education         lunch  \
# new_index
# 688        female        group B           bachelor's degree      standard
# 797        female        group C                some college      standard
# 438        female        group B             master's degree      standard
# 607          male        group A          associate's degree  free/reduced
# 625          male        group C                some college      standard
# ...           ...            ...                         ...           ...
# 291        female        group E             master's degree      standard
# 20           male        group C                 high school  free/reduced
# 593        female        group C                 high school  free/reduced
# 89         female        group D                some college      standard
# 84         female        group D                some college  free/reduced
#
# ...

# %% [markdown]
# # Sort Index

# %%
df_exam.sort_index()
# Out:
#            gender race/ethnicity parental level of education         lunch  \
# new_index
# 0            male        group B           bachelor's degree      standard
# 1          female        group B                some college  free/reduced
# 2          female        group E            some high school      standard
# 3            male        group D          associate's degree  free/reduced
# 4            male        group D                some college  free/reduced
# ...           ...            ...                         ...           ...
# 995        female        group D          associate's degree  free/reduced
# 996          male        group E          associate's degree      standard
# 997          male        group B          associate's degree  free/reduced
# 998        female        group C                some college  free/reduced
# 999          male        group C            some high school      standard
#
# ...

# %%
df_exam.sort_index(ascending=False)
# Out:
#            gender race/ethnicity parental level of education         lunch  \
# new_index
# 999          male        group C            some high school      standard
# 998        female        group C                some college  free/reduced
# 997          male        group B          associate's degree  free/reduced
# 996          male        group E          associate's degree      standard
# 995        female        group D          associate's degree  free/reduced
# ...           ...            ...                         ...           ...
# 4            male        group D                some college  free/reduced
# 3            male        group D          associate's degree  free/reduced
# 2          female        group E            some high school      standard
# 1          female        group B                some college  free/reduced
# 0            male        group B           bachelor's degree      standard
#
# ...
